# %%
import pandas as pd
pd.set_option("display.max_columns",None)
import seaborn as sns

# %%
data=pd.read_table(r"G:\IMARTICUS FINAL PROJECT\XYZCorp_LendingData.txt")
data.head()
# Out:
# H:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3254: DtypeWarning: Columns (17,45,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0     10.65       162.87     B        B2                       NaN  10+ years
# 1     15.27        59.83     C        C4                     Ryder   < 1 year
# 2     15.96        84.33     C        C5                       NaN  10+ years
# 3     13.49       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4     12.69        67.79     B        B5  University Medical Group     1 year
#
#   home_ownership  annual_inc verification_status   issue_d pymnt_plan  \
# 0           RENT     24000.0            Verified  Dec-2011          n
# 1           RENT     30000.0     Source Verified  Dec-2011          n
# 2           RENT     12252.0        Not Verified  Dec-2011          n
# 3           RENT     49200.0     Source Verified  Dec-2011          n
# 4           RENT     80000.0     Source Verified  Dec-2011          n
#
#                                                 desc         purpose  \
# 0    Borrower added on 12/22/11 > I need to upgra...     credit_card
# 1    Borrower added on 12/22/11 > I plan to use t...             car
# 2                                                NaN  small_business
# 3    Borrower added on 12/21/11 > to pay for prop...           other
# 4    Borrower added on 12/21/11 > I plan on combi...           other
#
#                   title zip_code addr_state    dti  delinq_2yrs  \
# 0              Computer    860xx         AZ  27.65          0.0
# 1                  bike    309xx         GA   1.00          0.0
# 2  real estate business    606xx         IL   8.72          0.0
# 3              personel    917xx         CA  20.00          0.0
# 4              Personal    972xx         OR  17.94          0.0
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0         Jan-1985             1.0                     NaN
# 1         Apr-1999             5.0                     NaN
# 2         Nov-2001             2.0                     NaN
# 3         Feb-1996             1.0                    35.0
# 4         Jan-1996             0.0                    38.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 0                     NaN       3.0      0.0    13648.0        83.7
# 1                     NaN       3.0      0.0     1687.0         9.4
# 2                     NaN       2.0      0.0     2956.0        98.5
# 3                     NaN      10.0      0.0     5598.0        21.0
# 4                     NaN      15.0      0.0    27783.0        53.9
#
#    total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0        9.0                   f        0.0            0.0   5861.071414
# 1        4.0                   f        0.0            0.0   1008.710000
# 2       10.0                   f        0.0            0.0   3003.653644
# 3       37.0                   f        0.0            0.0  12226.302212
# 4       38.0                   f      766.9          766.9   3242.170000
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          5831.78          5000.00         861.07                0.00
# 1          1008.71           456.46         435.17                0.00
# 2          3003.65          2400.00         603.65                0.00
# 3         12226.30         10000.00        2209.33               16.97
# 4          3242.17          2233.10        1009.07                0.00
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0        0.00                     0.00     Jan-2015           171.62
# 1      117.08                     1.11     Apr-2013           119.66
# 2        0.00                     0.00     Jun-2014           649.91
# 3        0.00                     0.00     Jan-2015           357.48
# 4        0.00                     0.00     Jan-2016            67.79
#
#   next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0          NaN           Jan-2016                         0.0
# 1          NaN           Sep-2013                         0.0
# 2          NaN           Jan-2016                         0.0
# 3          NaN           Jan-2015                         0.0
# 4     Feb-2016           Jan-2016                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN          1.0       INDIVIDUAL
# 1                          NaN          1.0       INDIVIDUAL
# 2                          NaN          1.0       INDIVIDUAL
# 3                          NaN          1.0       INDIVIDUAL
# 4                          NaN          1.0       INDIVIDUAL
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2               NaN        NaN                       NaN             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  \
# 0           NaN          NaN          NaN         NaN          NaN
# 1           NaN          NaN          NaN         NaN          NaN
# 2           NaN          NaN          NaN         NaN          NaN
# 3           NaN          NaN          NaN         NaN          NaN
# 4           NaN          NaN          NaN         NaN          NaN
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          NaN                 NaN           NaN      NaN          NaN
# 1          NaN                 NaN           NaN      NaN          NaN
# 2          NaN                 NaN           NaN      NaN          NaN
# 3          NaN                 NaN           NaN      NaN          NaN
# 4          NaN                 NaN           NaN      NaN          NaN
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          NaN         NaN       NaN               NaN     NaN          NaN
# 1          NaN         NaN       NaN               NaN     NaN          NaN
# 2          NaN         NaN       NaN               NaN     NaN          NaN
# 3          NaN         NaN       NaN               NaN     NaN          NaN
# 4          NaN         NaN       NaN               NaN     NaN          NaN
#
#    inq_last_12m  default_ind
# 0           NaN            0
# 1           NaN            1
# 2           NaN            0
# 3           NaN            0
# 4           NaN            0

# %%
data.shape
# Out:
# (855969, 73)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855969 entries, 0 to 855968
# Data columns (total 73 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           855969 non-null  int64
#  1   member_id                    855969 non-null  int64
#  2   loan_amnt                    855969 non-null  float64
#  3   funded_amnt                  855969 non-null  float64
#  4   funded_amnt_inv              855969 non-null  float64
#  5   term                         855969 non-null  object
#  6   int_rate                     855969 non-null  float64
#  7   installment                  855969 non-null  float64
#  8   grade                        855969 non-null  object
#  9   sub_grade                    855969 non-null  object
#  10  emp_title                    806526 non-null  object
#  11  emp_length                   812908 non-null  object
#  12  home_ownership               855969 non-null  object
#  13  annual_inc                   855969 non-null  float64
#  14  verification_status          855969 non-null  object
#  15  issue_d                      855969 non-null  object
#  16  pymnt_plan                   855969 non-null  object
#  17  desc                         121812 non-null  object
#  18  purpose                      855969 non-null  object
#  19  title                        855936 non-null  object
#  20  zip_code                     855969 non-null  object
#  21  addr_state                   855969 non-null  object
#  22  dti                          855969 non-null  float64
#  23  delinq_2yrs                  855969 non-null  float64
#  24  earliest_cr_line             855969 non-null  object
#  25  inq_last_6mths               855969 non-null  float64
#  26  mths_since_last_delinq       416157 non-null  float64
#  27  mths_since_last_record       131184 non-null  float64
#  28  open_acc                     855969 non-null  float64
#  29  pub_rec                      855969 non-null  float64
#  30  revol_bal                    855969 non-null  float64
#  31  revol_util                   855523 non-null  float64
#  32  total_acc                    855969 non-null  float64
#  33  initial_list_status          855969 non-null  object
#  34  out_prncp                    855969 non-null  float64
#  35  out_prncp_inv                855969 non-null  float64
#  36  total_pymnt                  855969 non-null  float64
#  37  total_pymnt_inv              855969 non-null  float64
#  38  total_rec_prncp              855969 non-null  float64
#  39  total_rec_int                855969 non-null  float64
#  40  total_rec_late_fee           855969 non-null  float64
#  41  recoveries                   855969 non-null  float64
#  42  collection_recovery_fee      855969 non-null  float64
#  43  last_pymnt_d                 847107 non-null  object
#  44  last_pymnt_amnt              855969 non-null  float64
#  45  next_pymnt_d                 602998 non-null  object
#  46  last_credit_pull_d           855919 non-null  object
#  47  collections_12_mths_ex_med   855913 non-null  float64
#  48  mths_since_last_major_derog  213139 non-null  float64
#  49  policy_code                  855969 non-null  float64
#  50  application_type             855969 non-null  object
#  51  annual_inc_joint             442 non-null     float64
#  52  dti_joint                    440 non-null     float64
#  53  verification_status_joint    442 non-null     object
#  54  acc_now_delinq               855969 non-null  float64
#  55  tot_coll_amt                 788656 non-null  float64
#  56  tot_cur_bal                  788656 non-null  float64
#  57  open_acc_6m                  13288 non-null   float64
#  58  open_il_6m                   13288 non-null   float64
#  59  open_il_12m                  13288 non-null   float64
#  60  open_il_24m                  13288 non-null   float64
#  61  mths_since_rcnt_il           12934 non-null   float64
#  62  total_bal_il                 13288 non-null   float64
#  63  il_util                      11609 non-null   float64
#  64  open_rv_12m                  13288 non-null   float64
#  65  open_rv_24m                  13288 non-null   float64
#  66  max_bal_bc                   13288 non-null   float64
#  67  all_util                     13288 non-null   float64
#  68  total_rev_hi_lim             788656 non-null  float64
#  69  inq_fi                       13288 non-null   float64
#  70  total_cu_tl                  13288 non-null   float64
#  71  inq_last_12m                 13288 non-null   float64
#  72  default_ind                  855969 non-null  int64
# dtypes: float64(49), int64(3), object(21)
# memory usage: 476.7+ MB

# %%
# check the null values
for i in data.columns:
    if data[i].isnull().any()==True:
        print(data[i].isnull().sum(),"==",i)
# Out:
# 49443 == emp_title
# 43061 == emp_length
# 734157 == desc
# 33 == title
# 439812 == mths_since_last_delinq
# 724785 == mths_since_last_record
# 446 == revol_util
# 8862 == last_pymnt_d
# 252971 == next_pymnt_d
# 50 == last_credit_pull_d
# 56 == collections_12_mths_ex_med
# 642830 == mths_since_last_major_derog
# 855527 == annual_inc_joint
# 855529 == dti_joint
# 855527 == verification_status_joint
# 67313 == tot_coll_amt
# 67313 == tot_cur_bal
# 842681 == open_acc_6m
# 842681 == open_il_6m
# 842681 == open_il_12m
# 842681 == open_il_24m
# 843035 == mths_since_rcnt_il
# 842681 == total_bal_il
# 844360 == il_util
# 842681 == open_rv_12m
# 842681 == open_rv_24m
# 842681 == max_bal_bc
# 842681 == all_util
# 67313 == total_rev_hi_lim
# 842681 == inq_fi
# 842681 == total_cu_tl
# 842681 == inq_last_12m

# %%
#drop the column wich has 50% is NA

for y in data.columns:
    if data[y].isnull().sum() >= len(data)/2:
        data.drop(y,axis=1,inplace=True)
#          print(y)

# %%
# again check the null values
for i in data.columns:
    if data[i].isnull().any()==True:
        print(data[i].isnull().sum(),"==",i)
# Out:
# 49443 == emp_title
# 43061 == emp_length
# 33 == title
# 446 == revol_util
# 8862 == last_pymnt_d
# 252971 == next_pymnt_d
# 50 == last_credit_pull_d
# 56 == collections_12_mths_ex_med
# 67313 == tot_coll_amt
# 67313 == tot_cur_bal
# 67313 == total_rev_hi_lim

# %%
#emp_length == 43061
data.emp_length.value_counts(dropna=False)

emp_len = {'< 1 year' : 0 , '1 year' : 1, '2 years' : 2, '3 years' : 3, '4 years' : 4, 
           '5 years' : 5,'6 years' : 6,
          '7 years' : 7, '8 years' : 8, '9 years' : 9, '10+ years' : 10}
emp_len

data['emp_length'] = data['emp_length'].map(emp_len)
data['emp_length'].value_counts(dropna=False)
data['emp_length'].mode()
data["emp_length"].fillna(data["emp_length"].mode()[0],inplace=True)

# %%
# change values from term column
data["term"].value_counts()
data['term'] = data['term'].map({' 36 months' : 0, ' 60 months' : 1})
data['term'].value_counts()
# Out:
# 0    600221
# 1    255748
# Name: term, dtype: int64

# %%
# again check the null values
for i in data.columns:
    if data[i].isnull().any()==True:
        print(data[i].isnull().sum(),"==",i)
# Out:
# 49443 == emp_title
# 33 == title
# 446 == revol_util
# 8862 == last_pymnt_d
# 252971 == next_pymnt_d
# 50 == last_credit_pull_d
# 56 == collections_12_mths_ex_med
# 67313 == tot_coll_amt
# 67313 == tot_cur_bal
# 67313 == total_rev_hi_lim

# %%
data['issue_d'] = pd.to_datetime(data['issue_d'])
#data = data.set_index(data['issue_d'])
#data = data.sort_index()
#data.drop("issue_d",axis=1,inplace=True)
#data.shape

# %%
# domain knowladge remove col which is not importnt
data_remov=["id","member_id","pymnt_plan","title","zip_code",
            "earliest_cr_line","last_credit_pull_d","next_pymnt_d","last_pymnt_d"]
    
data.drop(data_remov,axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# emp_title                     49443
# emp_length                        0
# home_ownership                    0
# annual_inc                        0
# verification_status               0
# issue_d                           0
# purpose                           0
# addr_state                        0
# dti                               0
# delinq_2yrs                       0
# inq_last_6mths                    0
# open_acc                          0
# pub_rec                           0
# revol_bal                         0
# revol_util                      446
# total_acc                         0
# initial_list_status               0
# out_prncp                         0
# out_prncp_inv                     0
# total_pymnt                       0
# total_pymnt_inv                   0
# total_rec_prncp                   0
# total_rec_int                     0
# total_rec_late_fee                0
# recoveries                        0
# collection_recovery_fee           0
# last_pymnt_amnt                   0
# collections_12_mths_ex_med       56
# policy_code                       0
# application_type                  0
# acc_now_delinq                    0
# tot_coll_amt                  67313
# tot_cur_bal                   67313
# total_rev_hi_lim              67313
# default_ind                       0
# dtype: int64

# %%
data.index
# Out:
# RangeIndex(start=0, stop=855969, step=1)

# %%
# fill the null values
for i in data.columns:
    if data[i].dtype=='object' or data[i].dtype=="bool":
        data[i].fillna(data[i].mode()[0],inplace=True)
    elif data[i].dtype=="int" or data[i].dtype=="float":
        data[i].fillna(round(data[i].mean()),inplace=True)

# %%
data.isnull().sum()
# Out:
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# sub_grade                     0
# emp_title                     0
# emp_length                    0
# home_ownership                0
# annual_inc                    0
# verification_status           0
# issue_d                       0
# purpose                       0
# addr_state                    0
# dti                           0
# delinq_2yrs                   0
# inq_last_6mths                0
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                    0
# total_acc                     0
# initial_list_status           0
# out_prncp                     0
# out_prncp_inv                 0
# total_pymnt                   0
# total_pymnt_inv               0
# total_rec_prncp               0
# total_rec_int                 0
# total_rec_late_fee            0
# recoveries                    0
# collection_recovery_fee       0
# last_pymnt_amnt               0
# collections_12_mths_ex_med    0
# policy_code                   0
# application_type              0
# acc_now_delinq                0
# tot_coll_amt                  0
# tot_cur_bal                   0
# total_rev_hi_lim              0
# default_ind                   0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855969 entries, 0 to 855968
# Data columns (total 43 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   855969 non-null  float64
#  1   funded_amnt                 855969 non-null  float64
#  2   funded_amnt_inv             855969 non-null  float64
#  3   term                        855969 non-null  int64
#  4   int_rate                    855969 non-null  float64
#  5   installment                 855969 non-null  float64
#  6   grade                       855969 non-null  object
#  7   sub_grade                   855969 non-null  object
#  8   emp_title                   855969 non-null  object
#  9   emp_length                  855969 non-null  float64
#  10  home_ownership              855969 non-null  object
#  11  annual_inc                  855969 non-null  float64
#  12  verification_status         855969 non-null  object
#  13  issue_d                     855969 non-null  datetime64[ns]
#  14  purpose                     855969 non-null  object
#  15  addr_state                  855969 non-null  object
#  16  dti                         855969 non-null  float64
#  17  delinq_2yrs                 855969 non-null  float64
#  18  inq_last_6mths              855969 non-null  float64
#  19  open_acc                    855969 non-null  float64
#  20  pub_rec                     855969 non-null  float64
#  21  revol_bal                   855969 non-null  float64
#  22  revol_util                  855969 non-null  float64
#  23  total_acc                   855969 non-null  float64
#  24  initial_list_status         855969 non-null  object
#  25  out_prncp                   855969 non-null  float64
#  26  out_prncp_inv               855969 non-null  float64
#  27  total_pymnt                 855969 non-null  float64
#  28  total_pymnt_inv             855969 non-null  float64
#  29  total_rec_prncp             855969 non-null  float64
#  30  total_rec_int               855969 non-null  float64
#  31  total_rec_late_fee          855969 non-null  float64
#  32  recoveries                  855969 non-null  float64
#  33  collection_recovery_fee     855969 non-null  float64
#  34  last_pymnt_amnt             855969 non-null  float64
#  35  collections_12_mths_ex_med  855969 non-null  float64
#  36  policy_code                 855969 non-null  float64
#  37  application_type            855969 non-null  object
#  38  acc_now_delinq              855969 non-null  float64
#  39  tot_coll_amt                855969 non-null  float64
#  40  tot_cur_bal                 855969 non-null  float64
#  41  total_rev_hi_lim            855969 non-null  float64
#  42  default_ind                 855969 non-null  int64
# dtypes: datetime64[ns](1), float64(31), int64(2), object(9)
# memory usage: 280.8+ MB

# %%
# divide data in train and test
# splite the data
train_df = data[(data['issue_d'] >= '2007-06-01') & (data['issue_d'] <= '2015-05-01')]
test_df  = data[(data['issue_d'] >= '2015-06-01') & (data['issue_d'] <= '2015-12-01')]

# %%
print('Train Dataset:',train_df.shape)
print('Test Dataset:',test_df.shape)
# Out:
# Train Dataset: (598978, 43)
# Test Dataset: (256991, 43)

# %%
test_df.head()
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 452272    25000.0      25000.0          25000.0     0      5.32       752.87
# 452273    18000.0      18000.0          18000.0     1     19.48       471.70
# 452274     7000.0       7000.0           7000.0     0      7.49       217.72
# 452275    20000.0      20000.0          20000.0     0     17.97       722.75
# 452276    15000.0      15000.0          15000.0     0      6.99       463.09
#
#        grade sub_grade           emp_title  emp_length home_ownership  \
# 452272     A        A1            Director         1.0       MORTGAGE
# 452273     E        E2    Software Manager         7.0           RENT
# 452274     A        A4             Carrier        10.0       MORTGAGE
# 452275     D        D4       Nurse Manager         7.0       MORTGAGE
# 452276     A        A3  Purchasing Manager         2.0       MORTGAGE
#
#         annual_inc verification_status    issue_d             purpose  \
# 452272    150000.0        Not Verified 2015-12-01         credit_card
# 452273    150000.0        Not Verified 2015-12-01  debt_consolidation
# 452274     59000.0        Not Verified 2015-12-01         credit_card
# 452275    180000.0        Not Verified 2015-12-01  debt_consolidation
# 452276     93000.0        Not Verified 2015-12-01         credit_card
#
#        addr_state    dti  delinq_2yrs  inq_last_6mths  open_acc  pub_rec  \
# 452272         VT   9.54          0.0             0.0       7.0      0.0
# 452273         CA   9.39          0.0             1.0      18.0      1.0
# 452274         MD  13.06          1.0             1.0      10.0      0.0
# 452275         TX  25.10          0.0             0.0      13.0      0.0
# 452276         MA  14.86          0.0             1.0       8.0      0.0
#
#         revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 452272    19339.0        42.5       18.0                   w   24357.97
# 452273    14052.0        40.7       27.0                   w   17820.50
# 452274    10467.0        24.2       34.0                   w    7000.00
# 452275    59126.0        92.1       30.0                   w   20000.00
# 452276    14914.0        43.2       17.0                   w   15000.00
#
#         out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 452272       24357.97       682.67           682.67           642.03
# 452273       17820.50       286.64           286.64           179.50
# 452274        7000.00         0.00             0.00             0.00
# 452275       20000.00         0.00             0.00             0.00
# 452276       15000.00         0.00             0.00             0.00
#
#         total_rec_int  total_rec_late_fee  recoveries  \
# 452272          40.64                 0.0         0.0
# 452273         107.14                 0.0         0.0
# 452274           0.00                 0.0         0.0
# 452275           0.00                 0.0         0.0
# 452276           0.00                 0.0         0.0
#
#         collection_recovery_fee  last_pymnt_amnt  collections_12_mths_ex_med  \
# 452272                      0.0           701.14                         0.0
# 452273                      0.0           335.34                         0.0
# 452274                      0.0             0.00                         0.0
# 452275                      0.0             0.00                         0.0
# 452276                      0.0             0.00                         0.0
#
#         policy_code application_type  acc_now_delinq  tot_coll_amt  \
# 452272          1.0       INDIVIDUAL             0.0           0.0
# 452273          1.0       INDIVIDUAL             0.0          60.0
# 452274          1.0       INDIVIDUAL             0.0           0.0
# 452275          1.0       INDIVIDUAL             0.0         418.0
# 452276          1.0       INDIVIDUAL             0.0           0.0
#
#         tot_cur_bal  total_rev_hi_lim  default_ind
# 452272     430856.0           45500.0            0
# 452273      36247.0           34500.0            0
# 452274      55222.0           43200.0            0
# 452275     277227.0           64200.0            0
# 452276     306430.0           34500.0            0

# %%
X_train = train_df.iloc[:,:-1]
Y_train = train_df.iloc[:,-1]
Y_train = Y_train.astype('int')

X_test = test_df.iloc[:,:-1]
Y_test = test_df.iloc[:,-1]
Y_test = Y_test.astype('int')

# %%
print(X_train.shape)
print(Y_train.shape)

print(X_test.shape)
print(Y_test.shape)
# Out:
# (598978, 42)
# (598978,)
# (256991, 42)
# (256991,)

# %%
# For preprocessing the data

colname_cat=[]
for x in data.columns:
    if data[x].dtype=='object':
        colname_cat.append(x)
print(colname_cat)

colname_cat1=[]
for x in X_train.columns:
    if X_train[x].dtype=='object':
        colname_cat1.append(x)
print(colname_cat1)

colname_cat2=[]
for x in X_test.columns:
    if X_test[x].dtype=='object':
        colname_cat2.append(x)
print(colname_cat2)
# Out:
# ['grade', 'sub_grade', 'emp_title', 'home_ownership', 'verification_status', 'purpose', 'addr_state', 'initial_list_status', 'application_type']
# ['grade', 'sub_grade', 'emp_title', 'home_ownership', 'verification_status', 'purpose', 'addr_state', 'initial_list_status', 'application_type']
# ['grade', 'sub_grade', 'emp_title', 'home_ownership', 'verification_status', 'purpose', 'addr_state', 'initial_list_status', 'application_type']

# %%
from sklearn import preprocessing

le=preprocessing.LabelEncoder()

for x in colname_cat:
    X_train[x]=le.fit_transform(X_train[x])
    X_test[x]=le.fit_transform(X_test[x])

# %%
data_corr=X_train.corr(method="pearson")
data_corr
# Out:
#                             loan_amnt  funded_amnt  funded_amnt_inv      term  \
# loan_amnt                    1.000000     0.998927         0.996507  0.412943
# funded_amnt                  0.998927     1.000000         0.997794  0.411470
# funded_amnt_inv              0.996507     0.997794         1.000000  0.412026
# term                         0.412943     0.411470         0.412026  1.000000
# int_rate                     0.151503     0.151909         0.152865  0.430213
# installment                  0.946536     0.948081         0.945607  0.151124
# grade                        0.157156     0.156957         0.156113  0.446973
# sub_grade                    0.163665     0.163352         0.162465  0.456712
# emp_title                   -0.042624    -0.042396        -0.041799 -0.014711
# emp_length                   0.091104     0.091523         0.093331  0.060839
# home_ownership              -0.203954    -0.203757        -0.203762 -0.117747
# annual_inc                   0.369446     0.369078         0.367934  0.068827
# verification_status          0.363307     0.362631         0.363275  0.242040
# purpose                     -0.152960    -0.154260        -0.156941 -0.046476
# addr_state                   0.017174     0.017369         0.017565  0.025068
# dti                          0.048383     0.049485         0.052152  0.096909
# delinq_2yrs                  0.004467     0.004903         0.005541  0.002856
# inq_last_6mths              -0.021916    -0.022287        -0.023706  0.003993
# open_acc                     0.200265     0.200946         0.201748  0.080685
# pub_rec                     -0.080959    -0.080505        -0.079373 -0.023949
# revol_bal                    0.340299     0.340132         0.339280  0.096031
# revol_util                   0.117876     0.118703         0.120090  0.083565
# total_acc                    0.227721     0.227667         0.227959  0.101176
# initial_list_status          0.087408     0.089335         0.093238  0.136400
# out_prncp                    0.565748     0.568097         0.570969  0.412818
# out_prncp_inv                0.565715     0.568065         0.570944  0.412799
# total_pymnt                  0.642346     0.641373         0.637166  0.133680
# total_pymnt_inv              0.642823     0.642084         0.642260  0.135072
# total_rec_prncp              0.526129     0.525237         0.521065 -0.008001
# total_rec_int                0.664136     0.663476         0.661537  0.484259
# total_rec_late_fee           0.032694     0.032295         0.029345  0.005432
# recoveries                   0.094960     0.094560         0.093060  0.075931
# collection_recovery_fee      0.069034     0.068840         0.066729  0.048666
# last_pymnt_amnt              0.273755     0.273482         0.272420  0.095123
# collections_12_mths_ex_med  -0.012715    -0.012516        -0.012077 -0.001163
# policy_code                       NaN          NaN              NaN       NaN
# application_type                  NaN          NaN              NaN       NaN
# acc_now_delinq               0.004660     0.004803         0.005064  0.005191
# tot_coll_amt                -0.003307    -0.003313        -0.003312 -0.001984
# tot_cur_bal                  0.313689     0.314012         0.313507  0.110336
# total_rev_hi_lim             0.289836     0.290083         0.289501  0.061678
#
#                             int_rate  installment     grade  sub_grade  \
# loan_amnt                   0.151503     0.946536  0.157156   0.163665
# funded_amnt                 0.151909     0.948081  0.156957   0.163352
# funded_amnt_inv             0.152865     0.945607  0.156113   0.162465
# term                        0.430213     0.151124  0.446973   0.456712
# int_rate                    1.000000     0.138699  0.954467   0.976770
# installment                 0.138699     1.000000  0.134257   0.140524
# grade                       0.954467     0.134257  1.000000   0.976837
# sub_grade                   0.976770     0.140524  0.976837   1.000000
# emp_title                   0.023498    -0.038174  0.024476   0.025239
# emp_length                  0.021629     0.078344  0.016570   0.016988
# home_ownership              0.061483    -0.169590  0.059904   0.062621
# annual_inc                 -0.063988     0.363544 -0.055661  -0.056356
# verification_status         0.239328     0.336892  0.219608   0.227402
# purpose                     0.144985    -0.136857  0.149391   0.152510
# addr_state                  0.006118     0.010545  0.006889   0.007469
# dti                         0.160613     0.038958  0.161848   0.166474
# delinq_2yrs                 0.064595     0.012920  0.067363   0.069651
# inq_last_6mths              0.222851     0.006256  0.205922   0.212320
# open_acc                   -0.001107     0.189417  0.006645   0.005927
# pub_rec                     0.056761    -0.070096  0.061649   0.064556
# revol_bal                  -0.021377     0.325010 -0.017594  -0.016318
# revol_util                  0.294182     0.133815  0.269225   0.280509
# total_acc                  -0.039202     0.206788 -0.033387  -0.034501
# initial_list_status        -0.067182     0.035170 -0.037941  -0.032905
# out_prncp                   0.070496     0.456071  0.131294   0.135211
# out_prncp_inv               0.070511     0.456044  0.131316   0.135235
# total_pymnt                 0.151096     0.675160  0.095071   0.099664
# total_pymnt_inv             0.152669     0.675652  0.094576   0.099133
# total_rec_prncp             0.010399     0.583984 -0.040762  -0.039579
# total_rec_int               0.479976     0.604962  0.438885   0.451021
# total_rec_late_fee          0.052668     0.042315  0.051900   0.053009
# recoveries                  0.122874     0.093564  0.111056   0.113916
# collection_recovery_fee     0.081827     0.069337  0.077310   0.079169
# last_pymnt_amnt             0.094605     0.276683  0.071863   0.074394
# collections_12_mths_ex_med  0.016528    -0.010869  0.021617   0.022437
# policy_code                      NaN          NaN       NaN        NaN
# application_type                 NaN          NaN       NaN        NaN
# acc_now_delinq              0.026713     0.007450  0.028457   0.028990
# tot_coll_amt                0.000614    -0.002730  0.000880   0.001251
# tot_cur_bal                -0.089332     0.283194 -0.080874  -0.083387
# total_rev_hi_lim           -0.150911     0.267244 -0.135454  -0.140404
#
#                             emp_title  emp_length  home_ownership  annual_inc  \
# loan_amnt                   -0.042624    0.091104       -0.203954    0.369446
# funded_amnt                 -0.042396    0.091523       -0.203757    0.369078
# funded_amnt_inv             -0.041799    0.093331       -0.203762    0.367934
# term                        -0.014711    0.060839       -0.117747    0.068827
# int_rate                     0.023498    0.021629        0.061483   -0.063988
# installment                 -0.038174    0.078344       -0.169590    0.363544
# grade                        0.024476    0.016570        0.059904   -0.055661
# sub_grade                    0.025239    0.016988        0.062621   -0.056356
# emp_title                    1.000000    0.103922       -0.008569   -0.044001
# emp_length                   0.103922    1.000000       -0.194491    0.046783
# home_ownership              -0.008569   -0.194491        1.000000   -0.178710
# annual_inc                  -0.044001    0.046783       -0.178710    1.000000
# verification_status          0.027314    0.117178       -0.070638    0.105512
# purpose                      0.017849   -0.023868        0.034875    0.008923
# addr_state                   0.009847    0.008821       -0.069715   -0.005154
# dti                          0.010908    0.051044        0.006033   -0.192813
# delinq_2yrs                  0.000881    0.024448       -0.051186    0.055699
# inq_last_6mths               0.008181   -0.008106       -0.049639    0.049833
# open_acc                    -0.040893    0.024498       -0.132478    0.152599
# pub_rec                      0.033676    0.047147        0.004882   -0.011768
# revol_bal                   -0.030507    0.079950       -0.163172    0.326759
# revol_util                  -0.019669    0.031583       -0.007772    0.036949
# total_acc                   -0.031084    0.096783       -0.225378    0.214387
# initial_list_status          0.004609    0.027291       -0.033278    0.035981
# out_prncp                   -0.004547    0.071982       -0.112293    0.193517
# out_prncp_inv               -0.004546    0.071984       -0.112292    0.193522
# total_pymnt                 -0.051417    0.048044       -0.142227    0.254306
# total_pymnt_inv             -0.050874    0.050300       -0.142896    0.254147
# total_rec_prncp             -0.051260    0.032263       -0.126781    0.233719
# total_rec_int               -0.027802    0.072118       -0.119297    0.190770
# total_rec_late_fee           0.002309   -0.011199        0.004567    0.014357
# recoveries                   0.004020    0.003366       -0.004459    0.012888
# collection_recovery_fee      0.005305    0.002937       -0.005795    0.011058
# last_pymnt_amnt             -0.031629    0.022321       -0.084018    0.125637
# collections_12_mths_ex_med   0.006965   -0.001625        0.003074   -0.002293
# policy_code                       NaN         NaN             NaN         NaN
# application_type                  NaN         NaN             NaN         NaN
# acc_now_delinq               0.004206    0.010518       -0.014946    0.016713
# tot_coll_amt                -0.001326   -0.000800       -0.002253    0.001323
# tot_cur_bal                 -0.039766    0.072936       -0.484206    0.442671
# total_rev_hi_lim            -0.025916    0.060439       -0.143538    0.280413
#
#                             verification_status   purpose  addr_state  \
# loan_amnt                              0.363307 -0.152960    0.017174
# funded_amnt                            0.362631 -0.154260    0.017369
# funded_amnt_inv                        0.363275 -0.156941    0.017565
# term                                   0.242040 -0.046476    0.025068
# int_rate                               0.239328  0.144985    0.006118
# installment                            0.336892 -0.136857    0.010545
# grade                                  0.219608  0.149391    0.006889
# sub_grade                              0.227402  0.152510    0.007469
# emp_title                              0.027314  0.017849    0.009847
# emp_length                             0.117178 -0.023868    0.008821
# home_ownership                        -0.070638  0.034875   -0.069715
# annual_inc                             0.105512  0.008923   -0.005154
# verification_status                    1.000000 -0.005622   -0.003937
# purpose                               -0.005622  1.000000   -0.007769
# addr_state                            -0.003937 -0.007769    1.000000
# dti                                    0.099311 -0.103926    0.042261
# delinq_2yrs                           -0.008945  0.012601    0.006579
# inq_last_6mths                         0.076344  0.051918    0.002424
# open_acc                               0.073140 -0.087874    0.030746
# pub_rec                                0.041318  0.015868   -0.004032
# revol_bal                              0.123317 -0.077115   -0.000522
# revol_util                             0.060438 -0.117843    0.003191
# total_acc                              0.097033 -0.066224    0.042974
# initial_list_status                   -0.019894 -0.076907    0.011523
# out_prncp                              0.165414 -0.120600    0.031812
# out_prncp_inv                          0.165380 -0.120593    0.031815
# total_pymnt                            0.280249 -0.070100   -0.005269
# total_pymnt_inv                        0.282100 -0.073086   -0.005123
# total_rec_prncp                        0.213550 -0.067453   -0.011423
# total_rec_int                          0.333960 -0.047555    0.016728
# total_rec_late_fee                     0.017238  0.025534    0.000403
# recoveries                             0.062457  0.015611   -0.003131
# collection_recovery_fee                0.040801  0.008983   -0.001255
# last_pymnt_amnt                        0.123675 -0.029232   -0.011731
# collections_12_mths_ex_med             0.010133  0.000829    0.007290
# policy_code                                 NaN       NaN         NaN
# application_type                            NaN       NaN         NaN
# acc_now_delinq                         0.012109  0.001219    0.003116
# tot_coll_amt                           0.001015  0.005446   -0.000046
# tot_cur_bal                            0.100686 -0.017427   -0.005293
# total_rev_hi_lim                       0.090062 -0.042614    0.001700
#
#                                  dti  delinq_2yrs  inq_last_6mths  open_acc  \
# loan_amnt                   0.048383     0.004467       -0.021916  0.200265
# funded_amnt                 0.049485     0.004903       -0.022287  0.200946
# funded_amnt_inv             0.052152     0.005541       -0.023706  0.201748
# term                        0.096909     0.002856        0.003993  0.080685
# int_rate                    0.160613     0.064595        0.222851 -0.001107
# installment                 0.038958     0.012920        0.006256  0.189417
# grade                       0.161848     0.067363        0.205922  0.006645
# sub_grade                   0.166474     0.069651        0.212320  0.005927
# emp_title                   0.010908     0.000881        0.008181 -0.040893
# emp_length                  0.051044     0.024448       -0.008106  0.024498
# home_ownership              0.006033    -0.051186       -0.049639 -0.132478
# annual_inc                 -0.192813     0.055699        0.049833  0.152599
# verification_status         0.099311    -0.008945        0.076344  0.073140
# purpose                    -0.103926     0.012601        0.051918 -0.087874
# addr_state                  0.042261     0.006579        0.002424  0.030746
# dti                         1.000000    -0.006363       -0.011333  0.302218
# delinq_2yrs                -0.006363     1.000000        0.019808  0.054255
# inq_last_6mths             -0.011333     0.019808        1.000000  0.107970
# open_acc                    0.302218     0.054255        0.107970  1.000000
# pub_rec                    -0.045808    -0.009716        0.048481 -0.027578
# revol_bal                   0.143376    -0.031707       -0.020362  0.227217
# revol_util                  0.189652    -0.014310       -0.093313 -0.135295
# total_acc                   0.225256     0.125966        0.136481  0.688091
# initial_list_status         0.047639     0.020955       -0.053875  0.059563
# out_prncp                   0.123156     0.039682       -0.094308  0.156172
# out_prncp_inv               0.123133     0.039677       -0.094315  0.156171
# total_pymnt                -0.056690    -0.026740        0.056015  0.086732
# total_pymnt_inv            -0.053837    -0.026138        0.054827  0.088161
# total_rec_prncp            -0.087507    -0.035888        0.039487  0.068477
# total_rec_int               0.062045     0.013645        0.069634  0.098676
# total_rec_late_fee         -0.010643     0.017733        0.021853 -0.009371
# recoveries                  0.012759     0.002107        0.044038  0.007443
# collection_recovery_fee     0.013239     0.003470        0.029425  0.008355
# last_pymnt_amnt            -0.051440    -0.016340        0.058078  0.043820
# collections_12_mths_ex_med  0.000336     0.050074        0.001959  0.011241
# policy_code                      NaN          NaN             NaN       NaN
# application_type                 NaN          NaN             NaN       NaN
# acc_now_delinq              0.008110     0.132284       -0.005350  0.017461
# tot_coll_amt               -0.003558     0.000023        0.002225 -0.000300
# tot_cur_bal                -0.017722     0.067685        0.042539  0.231405
# total_rev_hi_lim            0.061401    -0.038500        0.007077  0.298272
#
#                              pub_rec  revol_bal  revol_util  total_acc  \
# loan_amnt                  -0.080959   0.340299    0.117876   0.227721
# funded_amnt                -0.080505   0.340132    0.118703   0.227667
# funded_amnt_inv            -0.079373   0.339280    0.120090   0.227959
# term                       -0.023949   0.096031    0.083565   0.101176
# int_rate                    0.056761  -0.021377    0.294182  -0.039202
# installment                -0.070096   0.325010    0.133815   0.206788
# grade                       0.061649  -0.017594    0.269225  -0.033387
# sub_grade                   0.064556  -0.016318    0.280509  -0.034501
# emp_title                   0.033676  -0.030507   -0.019669  -0.031084
# emp_length                  0.047147   0.079950    0.031583   0.096783
# home_ownership              0.004882  -0.163172   -0.007772  -0.225378
# annual_inc                 -0.011768   0.326759    0.036949   0.214387
# verification_status         0.041318   0.123317    0.060438   0.097033
# purpose                     0.015868  -0.077115   -0.117843  -0.066224
# addr_state                 -0.004032  -0.000522    0.003191   0.042974
# dti                        -0.045808   0.143376    0.189652   0.225256
# delinq_2yrs                -0.009716  -0.031707   -0.014310   0.125966
# inq_last_6mths              0.048481  -0.020362   -0.093313   0.136481
# open_acc                   -0.027578   0.227217   -0.135295   0.688091
# pub_rec                     1.000000  -0.102095   -0.072064   0.011279
# revol_bal                  -0.102095   1.000000    0.212481   0.195132
# revol_util                 -0.072064   0.212481    1.000000  -0.106343
# total_acc                   0.011279   0.195132   -0.106343   1.000000
# initial_list_status         0.027704   0.037529   -0.014211   0.052964
# out_prncp                   0.001393   0.209541    0.090873   0.127116
# out_prncp_inv               0.001377   0.209526    0.090864   0.127104
# total_pymnt                -0.093195   0.205359    0.076665   0.143179
# total_pymnt_inv            -0.092263   0.205446    0.078443   0.144200
# total_rec_prncp            -0.089483   0.176800    0.022209   0.129739
# total_rec_int              -0.056115   0.189170    0.198708   0.111978
# total_rec_late_fee         -0.012218   0.000723    0.020327  -0.006891
# recoveries                 -0.014418   0.016347    0.031006   0.012318
# collection_recovery_fee    -0.008495   0.012740    0.020615   0.013683
# last_pymnt_amnt            -0.030678   0.077047   -0.010881   0.102006
# collections_12_mths_ex_med  0.021839  -0.020317   -0.031682   0.012039
# policy_code                      NaN        NaN         NaN        NaN
# application_type                 NaN        NaN         NaN        NaN
# acc_now_delinq              0.001750  -0.000017   -0.025209   0.027312
# tot_coll_amt                0.004874  -0.004929   -0.006970   0.005278
# tot_cur_bal                -0.074736   0.420805    0.066618   0.296972
# total_rev_hi_lim           -0.100418   0.791246   -0.116891   0.233873
#
#                             initial_list_status  out_prncp  out_prncp_inv  \
# loan_amnt                              0.087408   0.565748       0.565715
# funded_amnt                            0.089335   0.568097       0.568065
# funded_amnt_inv                        0.093238   0.570969       0.570944
# term                                   0.136400   0.412818       0.412799
# int_rate                              -0.067182   0.070496       0.070511
# installment                            0.035170   0.456071       0.456044
# grade                                 -0.037941   0.131294       0.131316
# sub_grade                             -0.032905   0.135211       0.135235
# emp_title                              0.004609  -0.004547      -0.004546
# emp_length                             0.027291   0.071982       0.071984
# home_ownership                        -0.033278  -0.112293      -0.112292
# annual_inc                             0.035981   0.193517       0.193522
# verification_status                   -0.019894   0.165414       0.165380
# purpose                               -0.076907  -0.120600      -0.120593
# addr_state                             0.011523   0.031812       0.031815
# dti                                    0.047639   0.123156       0.123133
# delinq_2yrs                            0.020955   0.039682       0.039677
# inq_last_6mths                        -0.053875  -0.094308      -0.094315
# open_acc                               0.059563   0.156172       0.156171
# pub_rec                                0.027704   0.001393       0.001377
# revol_bal                              0.037529   0.209541       0.209526
# revol_util                            -0.014211   0.090873       0.090864
# total_acc                              0.052964   0.127116       0.127104
# initial_list_status                    1.000000   0.239249       0.239424
# out_prncp                              0.239249   1.000000       0.999998
# out_prncp_inv                          0.239424   0.999998       1.000000
# total_pymnt                           -0.125823  -0.146246      -0.146306
# total_pymnt_inv                       -0.121830  -0.142562      -0.142615
# total_rec_prncp                       -0.122574  -0.276518      -0.276561
# total_rec_int                         -0.064292   0.346006       0.345919
# total_rec_late_fee                    -0.030916  -0.036271      -0.036276
# recoveries                            -0.047526  -0.111042      -0.111036
# collection_recovery_fee               -0.035010  -0.076960      -0.076955
# last_pymnt_amnt                       -0.032088  -0.336321      -0.336302
# collections_12_mths_ex_med             0.016717   0.018583       0.018576
# policy_code                                 NaN        NaN            NaN
# application_type                            NaN        NaN            NaN
# acc_now_delinq                         0.005860   0.015276       0.015272
# tot_coll_amt                           0.002343  -0.000768      -0.000769
# tot_cur_bal                            0.030229   0.173244       0.173251
# total_rev_hi_lim                       0.036445   0.172279       0.172273
#
#                             total_pymnt  total_pymnt_inv  total_rec_prncp  \
# loan_amnt                      0.642346         0.642823         0.526129
# funded_amnt                    0.641373         0.642084         0.525237
# funded_amnt_inv                0.637166         0.642260         0.521065
# term                           0.133680         0.135072        -0.008001
# int_rate                       0.151096         0.152669         0.010399
# installment                    0.675160         0.675652         0.583984
# grade                          0.095071         0.094576        -0.040762
# sub_grade                      0.099664         0.099133        -0.039579
# emp_title                     -0.051417        -0.050874        -0.051260
# emp_length                     0.048044         0.050300         0.032263
# home_ownership                -0.142227        -0.142896        -0.126781
# annual_inc                     0.254306         0.254147         0.233719
# verification_status            0.280249         0.282100         0.213550
# purpose                       -0.070100        -0.073086        -0.067453
# addr_state                    -0.005269        -0.005123        -0.011423
# dti                           -0.056690        -0.053837        -0.087507
# delinq_2yrs                   -0.026740        -0.026138        -0.035888
# inq_last_6mths                 0.056015         0.054827         0.039487
# open_acc                       0.086732         0.088161         0.068477
# pub_rec                       -0.093195        -0.092263        -0.089483
# revol_bal                      0.205359         0.205446         0.176800
# revol_util                     0.076665         0.078443         0.022209
# total_acc                      0.143179         0.144200         0.129739
# initial_list_status           -0.125823        -0.121830        -0.122574
# out_prncp                     -0.146246        -0.142562        -0.276518
# out_prncp_inv                 -0.146306        -0.142615        -0.276561
# total_pymnt                    1.000000         0.997436         0.963070
# total_pymnt_inv                0.997436         1.000000         0.960337
# total_rec_prncp                0.963070         0.960337         1.000000
# total_rec_int                  0.626397         0.625784         0.400789
# total_rec_late_fee             0.035468         0.032751         0.012881
# recoveries                     0.002557         0.001703        -0.083042
# collection_recovery_fee        0.013572         0.011902        -0.053804
# last_pymnt_amnt                0.645635         0.646028         0.733803
# collections_12_mths_ex_med    -0.032379        -0.031986        -0.032599
# policy_code                         NaN              NaN              NaN
# application_type                    NaN              NaN              NaN
# acc_now_delinq                -0.008014        -0.007737        -0.011112
# tot_coll_amt                  -0.002972        -0.002982        -0.002595
# tot_cur_bal                    0.208847         0.209268         0.193458
# total_rev_hi_lim               0.170337         0.170561         0.165488
#
#                             total_rec_int  total_rec_late_fee  recoveries  \
# loan_amnt                        0.664136            0.032694    0.094960
# funded_amnt                      0.663476            0.032295    0.094560
# funded_amnt_inv                  0.661537            0.029345    0.093060
# term                             0.484259            0.005432    0.075931
# int_rate                         0.479976            0.052668    0.122874
# installment                      0.604962            0.042315    0.093564
# grade                            0.438885            0.051900    0.111056
# sub_grade                        0.451021            0.053009    0.113916
# emp_title                       -0.027802            0.002309    0.004020
# emp_length                       0.072118           -0.011199    0.003366
# home_ownership                  -0.119297            0.004567   -0.004459
# annual_inc                       0.190770            0.014357    0.012888
# verification_status              0.333960            0.017238    0.062457
# purpose                         -0.047555            0.025534    0.015611
# addr_state                       0.016728            0.000403   -0.003131
# dti                              0.062045           -0.010643    0.012759
# delinq_2yrs                      0.013645            0.017733    0.002107
# inq_last_6mths                   0.069634            0.021853    0.044038
# open_acc                         0.098676           -0.009371    0.007443
# pub_rec                         -0.056115           -0.012218   -0.014418
# revol_bal                        0.189170            0.000723    0.016347
# revol_util                       0.198708            0.020327    0.031006
# total_acc                        0.111978           -0.006891    0.012318
# initial_list_status             -0.064292           -0.030916   -0.047526
# out_prncp                        0.346006           -0.036271   -0.111042
# out_prncp_inv                    0.345919           -0.036276   -0.111036
# total_pymnt                      0.626397            0.035468    0.002557
# total_pymnt_inv                  0.625784            0.032751    0.001703
# total_rec_prncp                  0.400789            0.012881   -0.083042
# total_rec_int                    1.000000            0.067128    0.045766
# total_rec_late_fee               0.067128            1.000000    0.083696
# recoveries                       0.045766            0.083696    1.000000
# collection_recovery_fee          0.038210            0.077464    0.804389
# last_pymnt_amnt                  0.075641           -0.021125   -0.056655
# collections_12_mths_ex_med      -0.015363           -0.002833   -0.002868
# policy_code                           NaN                 NaN         NaN
# application_type                      NaN                 NaN         NaN
# acc_now_delinq                   0.004959            0.002395    0.001662
# tot_coll_amt                    -0.002534           -0.000384   -0.000654
# tot_cur_bal                      0.153223            0.008544    0.005147
# total_rev_hi_lim                 0.101692           -0.003959    0.003360
#
#                             collection_recovery_fee  last_pymnt_amnt  \
# loan_amnt                                  0.069034         0.273755
# funded_amnt                                0.068840         0.273482
# funded_amnt_inv                            0.066729         0.272420
# term                                       0.048666         0.095123
# int_rate                                   0.081827         0.094605
# installment                                0.069337         0.276683
# grade                                      0.077310         0.071863
# sub_grade                                  0.079169         0.074394
# emp_title                                  0.005305        -0.031629
# emp_length                                 0.002937         0.022321
# home_ownership                            -0.005795        -0.084018
# annual_inc                                 0.011058         0.125637
# verification_status                        0.040801         0.123675
# purpose                                    0.008983        -0.029232
# addr_state                                -0.001255        -0.011731
# dti                                        0.013239        -0.051440
# delinq_2yrs                                0.003470        -0.016340
# inq_last_6mths                             0.029425         0.058078
# open_acc                                   0.008355         0.043820
# pub_rec                                   -0.008495        -0.030678
# revol_bal                                  0.012740         0.077047
# revol_util                                 0.020615        -0.010881
# total_acc                                  0.013683         0.102006
# initial_list_status                       -0.035010        -0.032088
# out_prncp                                 -0.076960        -0.336321
# out_prncp_inv                             -0.076955        -0.336302
# total_pymnt                                0.013572         0.645635
# total_pymnt_inv                            0.011902         0.646028
# total_rec_prncp                           -0.053804         0.733803
# total_rec_int                              0.038210         0.075641
# total_rec_late_fee                         0.077464        -0.021125
# recoveries                                 0.804389        -0.056655
# collection_recovery_fee                    1.000000        -0.039070
# last_pymnt_amnt                           -0.039070         1.000000
# collections_12_mths_ex_med                -0.001471        -0.013912
# policy_code                                     NaN              NaN
# application_type                                NaN              NaN
# acc_now_delinq                             0.001078        -0.003040
# tot_coll_amt                              -0.000312        -0.001866
# tot_cur_bal                                0.006244         0.117204
# total_rev_hi_lim                           0.004044         0.076337
#
#                             collections_12_mths_ex_med  policy_code  \
# loan_amnt                                    -0.012715          NaN
# funded_amnt                                  -0.012516          NaN
# funded_amnt_inv                              -0.012077          NaN
# term                                         -0.001163          NaN
# int_rate                                      0.016528          NaN
# installment                                  -0.010869          NaN
# grade                                         0.021617          NaN
# sub_grade                                     0.022437          NaN
# emp_title                                     0.006965          NaN
# emp_length                                   -0.001625          NaN
# home_ownership                                0.003074          NaN
# annual_inc                                   -0.002293          NaN
# verification_status                           0.010133          NaN
# purpose                                       0.000829          NaN
# addr_state                                    0.007290          NaN
# dti                                           0.000336          NaN
# delinq_2yrs                                   0.050074          NaN
# inq_last_6mths                                0.001959          NaN
# open_acc                                      0.011241          NaN
# pub_rec                                       0.021839          NaN
# revol_bal                                    -0.020317          NaN
# revol_util                                   -0.031682          NaN
# total_acc                                     0.012039          NaN
# initial_list_status                           0.016717          NaN
# out_prncp                                     0.018583          NaN
# out_prncp_inv                                 0.018576          NaN
# total_pymnt                                  -0.032379          NaN
# total_pymnt_inv                              -0.031986          NaN
# total_rec_prncp                              -0.032599          NaN
# total_rec_int                                -0.015363          NaN
# total_rec_late_fee                           -0.002833          NaN
# recoveries                                   -0.002868          NaN
# collection_recovery_fee                      -0.001471          NaN
# last_pymnt_amnt                              -0.013912          NaN
# collections_12_mths_ex_med                    1.000000          NaN
# policy_code                                        NaN          NaN
# application_type                                   NaN          NaN
# acc_now_delinq                                0.056604          NaN
# tot_coll_amt                                  0.007695          NaN
# tot_cur_bal                                  -0.007384          NaN
# total_rev_hi_lim                             -0.015213          NaN
#
#                             application_type  acc_now_delinq  tot_coll_amt  \
# loan_amnt                                NaN        0.004660     -0.003307
# funded_amnt                              NaN        0.004803     -0.003313
# funded_amnt_inv                          NaN        0.005064     -0.003312
# term                                     NaN        0.005191     -0.001984
# int_rate                                 NaN        0.026713      0.000614
# installment                              NaN        0.007450     -0.002730
# grade                                    NaN        0.028457      0.000880
# sub_grade                                NaN        0.028990      0.001251
# emp_title                                NaN        0.004206     -0.001326
# emp_length                               NaN        0.010518     -0.000800
# home_ownership                           NaN       -0.014946     -0.002253
# annual_inc                               NaN        0.016713      0.001323
# verification_status                      NaN        0.012109      0.001015
# purpose                                  NaN        0.001219      0.005446
# addr_state                               NaN        0.003116     -0.000046
# dti                                      NaN        0.008110     -0.003558
# delinq_2yrs                              NaN        0.132284      0.000023
# inq_last_6mths                           NaN       -0.005350      0.002225
# open_acc                                 NaN        0.017461     -0.000300
# pub_rec                                  NaN        0.001750      0.004874
# revol_bal                                NaN       -0.000017     -0.004929
# revol_util                               NaN       -0.025209     -0.006970
# total_acc                                NaN        0.027312      0.005278
# initial_list_status                      NaN        0.005860      0.002343
# out_prncp                                NaN        0.015276     -0.000768
# out_prncp_inv                            NaN        0.015272     -0.000769
# total_pymnt                              NaN       -0.008014     -0.002972
# total_pymnt_inv                          NaN       -0.007737     -0.002982
# total_rec_prncp                          NaN       -0.011112     -0.002595
# total_rec_int                            NaN        0.004959     -0.002534
# total_rec_late_fee                       NaN        0.002395     -0.000384
# recoveries                               NaN        0.001662     -0.000654
# collection_recovery_fee                  NaN        0.001078     -0.000312
# last_pymnt_amnt                          NaN       -0.003040     -0.001866
# collections_12_mths_ex_med               NaN        0.056604      0.007695
# policy_code                              NaN             NaN           NaN
# application_type                         NaN             NaN           NaN
# acc_now_delinq                           NaN        1.000000      0.000247
# tot_coll_amt                             NaN        0.000247      1.000000
# tot_cur_bal                              NaN        0.021458      0.000150
# total_rev_hi_lim                         NaN        0.007958     -0.004097
#
#                             tot_cur_bal  total_rev_hi_lim
# loan_amnt                      0.313689          0.289836
# funded_amnt                    0.314012          0.290083
# funded_amnt_inv                0.313507          0.289501
# term                           0.110336          0.061678
# int_rate                      -0.089332         -0.150911
# installment                    0.283194          0.267244
# grade                         -0.080874         -0.135454
# sub_grade                     -0.083387         -0.140404
# emp_title                     -0.039766         -0.025916
# emp_length                     0.072936          0.060439
# home_ownership                -0.484206         -0.143538
# annual_inc                     0.442671          0.280413
# verification_status            0.100686          0.090062
# purpose                       -0.017427         -0.042614
# addr_state                    -0.005293          0.001700
# dti                           -0.017722          0.061401
# delinq_2yrs                    0.067685         -0.038500
# inq_last_6mths                 0.042539          0.007077
# open_acc                       0.231405          0.298272
# pub_rec                       -0.074736         -0.100418
# revol_bal                      0.420805          0.791246
# revol_util                     0.066618         -0.116891
# total_acc                      0.296972          0.233873
# initial_list_status            0.030229          0.036445
# out_prncp                      0.173244          0.172279
# out_prncp_inv                  0.173251          0.172273
# total_pymnt                    0.208847          0.170337
# total_pymnt_inv                0.209268          0.170561
# total_rec_prncp                0.193458          0.165488
# total_rec_int                  0.153223          0.101692
# total_rec_late_fee             0.008544         -0.003959
# recoveries                     0.005147          0.003360
# collection_recovery_fee        0.006244          0.004044
# last_pymnt_amnt                0.117204          0.076337
# collections_12_mths_ex_med    -0.007384         -0.015213
# policy_code                         NaN               NaN
# application_type                    NaN               NaN
# acc_now_delinq                 0.021458          0.007958
# tot_coll_amt                   0.000150         -0.004097
# tot_cur_bal                    1.000000          0.373921
# total_rev_hi_lim               0.373921          1.000000

# %%
# remove col on corrlelation
X_train_drop=["issue_d","sub_grade","loan_amnt","funded_amnt","installment","grade",
               "out_prncp","total_pymnt_inv","total_rec_prncp","policy_code",
               "revol_bal","last_pymnt_amnt","recoveries","total_rec_int","open_acc"]

# %%
X_train.drop(X_train_drop,axis=1,inplace=True)
X_test.drop(X_train_drop,axis=1,inplace=True)

# %%
X_train.drop("application_type",axis=1,inplace=True)
X_test.drop("application_type",axis=1,inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
X_train_corr=X_train.corr(method="pearson")
plt.figure(figsize = (50,50))
sns.heatmap(X_train_corr, vmin = -1.0, vmax = 1.0, annot = True)
# Out:
# <AxesSubplot:>

# %%
#VIF check the multicolinearity
 
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

vif_df = pd.DataFrame()
vif_df["features"] = X_train.columns
vif_df["VIF Factor"] = [vif(X_train.values, i) for i in range(X_train.shape[1])]
vif_df.round(2)
# Out:
#                       features  VIF Factor
# 0              funded_amnt_inv       32.59
# 1                         term        2.24
# 2                     int_rate       16.77
# 3                    emp_title        4.15
# 4                   emp_length        3.93
# 5               home_ownership        3.78
# 6                   annual_inc        3.98
# 7          verification_status        3.27
# 8                      purpose        2.42
# 9                   addr_state        3.17
# 10                         dti        7.16
# 11                 delinq_2yrs        1.20
# 12              inq_last_6mths        1.76
# 13                     pub_rec        1.16
# 14                  revol_util        8.01
# 15                   total_acc        6.93
# 16         initial_list_status        1.77
# 17               out_prncp_inv        7.95
# 18                 total_pymnt       13.54
# 19          total_rec_late_fee        1.03
# 20     collection_recovery_fee        1.12
# 21  collections_12_mths_ex_med        1.02
# 22              acc_now_delinq        1.03
# 23                tot_coll_amt        1.00
# 24                 tot_cur_bal        3.38
# 25            total_rev_hi_lim        2.41

# %%
# removing col which has multicolinearity


print(vif_df["VIF Factor"].max())
X_train.drop("funded_amnt_inv",axis=1,inplace=True)
X_test.drop("funded_amnt_inv",axis=1,inplace=True)
# Out:
# 32.59382317764893

# %%
print(vif_df["VIF Factor"].max())
X_train.drop("int_rate",axis=1,inplace=True)
X_test.drop("int_rate",axis=1,inplace=True)
# Out:
# 32.59382317764893

# %%
print(vif_df["VIF Factor"].max())
X_train.drop("total_acc",axis=1,inplace=True)
X_test.drop("total_acc",axis=1,inplace=True)
# Out:
# 32.59382317764893

# %%
print(vif_df["VIF Factor"].max())
X_train.drop("revol_util",axis=1,inplace=True)
X_test.drop("revol_util",axis=1,inplace=True)
# Out:
# 32.59382317764893

# %%
print(vif_df["VIF Factor"].max())
X_train.drop("dti",axis=1,inplace=True)
X_test.drop("dti",axis=1,inplace=True)
# Out:
# 32.59382317764893

# %%
vif_df = pd.DataFrame()
vif_df["features"] = X_train.columns
vif_df["VIF Factor"] = [vif(X_train.values, i) for i in range(X_train.shape[1])]
vif_df.round(2)
# Out:
#                       features  VIF Factor
# 0                         term        1.86
# 1                    emp_title        3.90
# 2                   emp_length        3.62
# 3               home_ownership        2.99
# 4                   annual_inc        3.67
# 5          verification_status        3.13
# 6                      purpose        2.17
# 7                   addr_state        2.95
# 8                  delinq_2yrs        1.16
# 9               inq_last_6mths        1.55
# 10                     pub_rec        1.14
# 11         initial_list_status        1.74
# 12               out_prncp_inv        2.49
# 13                 total_pymnt        3.25
# 14          total_rec_late_fee        1.02
# 15     collection_recovery_fee        1.03
# 16  collections_12_mths_ex_med        1.02
# 17              acc_now_delinq        1.02
# 18                tot_coll_amt        1.00
# 19                 tot_cur_bal        3.10
# 20            total_rev_hi_lim        2.25

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Logistic Model on Training Data

# %%
from sklearn.linear_model import LogisticRegression
 
# create a model
classifier=LogisticRegression()

#fitting traing data to the model
classifier.fit(X_train,Y_train)

#predic for training data

Y_pred_X_train=classifier.predict(X_train)

# %%
# check the eveluation model matrix

from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

cfm=confusion_matrix(Y_train,Y_pred_X_train)
print(cfm)

print("classification report: ")
print(classification_report(Y_train,Y_pred_X_train))

acc = accuracy_score(Y_train,Y_pred_X_train)
print("acccurecy of the model: ",acc)
# Out:
# [[551278   1544]
#  [ 17857  28299]]
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98    552822
#            1       0.95      0.61      0.74     46156
#
#     accuracy                           0.97    598978
#    macro avg       0.96      0.81      0.86    598978
# weighted avg       0.97      0.97      0.96    598978
#
# acccurecy of the model:  0.9676098287416233

# %% [markdown]
# ## Logistic Model on Testing Data

# %%
# predic for testing data
Y_pred=classifier.predict(X_test)

# %%
cfm=confusion_matrix(Y_test,Y_pred)
print(cfm)

print("classification report: ")
print(classification_report(Y_test,Y_pred))

acc = accuracy_score(Y_test,Y_pred)
print("acccurecy of the model: ",acc)
# Out:
# [[256620     60]
#  [   200    111]]
# classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    256680
#            1       0.65      0.36      0.46       311
#
#     accuracy                           1.00    256991
#    macro avg       0.82      0.68      0.73    256991
# weighted avg       1.00      1.00      1.00    256991
#
# acccurecy of the model:  0.9989882914187657

# %% [markdown]
# ##  Decision Tree Model On Training Data

# %%
#predicting using the Decision_Tree_Classifier
 
from sklearn.tree import DecisionTreeClassifier

model_DecisionTree=DecisionTreeClassifier(criterion="gini",random_state=10)

# fit the model on the data and predict the values

model_DecisionTree.fit(X_train,Y_train)

#predict for testing data 

Y_pred_X_train=model_DecisionTree.predict(X_train)

# %%
# check the eveluation model matrix
cfm=confusion_matrix(Y_train,Y_pred_X_train)
print(cfm)

print("classification report: ")
print(classification_report(Y_train,Y_pred_X_train))

acc = accuracy_score(Y_train,Y_pred_X_train)
print("acccurecy of the model: ",acc)
# Out:
# [[552822      0]
#  [     0  46156]]
# classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    552822
#            1       1.00      1.00      1.00     46156
#
#     accuracy                           1.00    598978
#    macro avg       1.00      1.00      1.00    598978
# weighted avg       1.00      1.00      1.00    598978
#
# acccurecy of the model:  1.0

# %% [markdown]
# ## Decision Tree Model on Testing Data

# %%
# predict for testing data
Y_pred=model_DecisionTree.predict(X_test)

# %%
cfm=confusion_matrix(Y_test,Y_pred)
print(cfm)

print("Classification report: ")
print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test, Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# [[ 62579 194101]
#  [    13    298]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.24      0.39    256680
#            1       0.00      0.96      0.00       311
#
#     accuracy                           0.24    256991
#    macro avg       0.50      0.60      0.20    256991
# weighted avg       1.00      0.24      0.39    256991
#
# Accuracy of the model:  0.2446661556241269

# %% [markdown]
# ## RANDOM FOREST Model On Training Data

# %%
# RANDOM FOREST MODEL    using  Bagging technique
from sklearn.ensemble import RandomForestClassifier

model_RandomForest = RandomForestClassifier(n_estimators=10,random_state=10)
# n_estimators=10,...,101 how many bags or DT model built in the memory background
#n_estimators= frandom values
# prunning can be aslo done here also

#fit the model on the data and predict the value


model_RandomForest = model_RandomForest.fit(X_train,Y_train)

# %%
# predict on training data
Y_pred_X_train=model_RandomForest.predict(X_train)

# %%
# check the eveluation model matrix
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report


cfm=confusion_matrix(Y_train,Y_pred_X_train)
print(cfm)

print("classification report: ")
print(classification_report(Y_train,Y_pred_X_train))

acc = accuracy_score(Y_train,Y_pred_X_train)
print("acccurecy of the model: ",acc)
# Out:
# [[552781     41]
#  [  2025  44131]]
# classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    552822
#            1       1.00      0.96      0.98     46156
#
#     accuracy                           1.00    598978
#    macro avg       1.00      0.98      0.99    598978
# weighted avg       1.00      1.00      1.00    598978
#
# acccurecy of the model:  0.9965507915148804

# %% [markdown]
# ## RANDOM FOREST Model On Testing  Data

# %%
# predic for test data
Y_pred=model_RandomForest.predict(X_test)

# %%
# check the eveluation model matrix
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report

print(confusion_matrix(Y_test,Y_pred))
print(accuracy_score(Y_test, Y_pred))
print(classification_report(Y_test,Y_pred))
# Out:
# [[232824  23856]
#  [    58    253]]
# 0.906946157647544
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95    256680
#            1       0.01      0.81      0.02       311
#
#     accuracy                           0.91    256991
#    macro avg       0.51      0.86      0.49    256991
# weighted avg       1.00      0.91      0.95    256991

# %%
data1=pd.read_table(r"G:\IMARTICUS FINAL PROJECT\XYZCorp_LendingData.txt")
data1.head()
# Out:
# H:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3254: DtypeWarning: Columns (17,45,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0     10.65       162.87     B        B2                       NaN  10+ years
# 1     15.27        59.83     C        C4                     Ryder   < 1 year
# 2     15.96        84.33     C        C5                       NaN  10+ years
# 3     13.49       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4     12.69        67.79     B        B5  University Medical Group     1 year
#
#   home_ownership  annual_inc verification_status   issue_d pymnt_plan  \
# 0           RENT     24000.0            Verified  Dec-2011          n
# 1           RENT     30000.0     Source Verified  Dec-2011          n
# 2           RENT     12252.0        Not Verified  Dec-2011          n
# 3           RENT     49200.0     Source Verified  Dec-2011          n
# 4           RENT     80000.0     Source Verified  Dec-2011          n
#
#                                                 desc         purpose  \
# 0    Borrower added on 12/22/11 > I need to upgra...     credit_card
# 1    Borrower added on 12/22/11 > I plan to use t...             car
# 2                                                NaN  small_business
# 3    Borrower added on 12/21/11 > to pay for prop...           other
# 4    Borrower added on 12/21/11 > I plan on combi...           other
#
#                   title zip_code addr_state    dti  delinq_2yrs  \
# 0              Computer    860xx         AZ  27.65          0.0
# 1                  bike    309xx         GA   1.00          0.0
# 2  real estate business    606xx         IL   8.72          0.0
# 3              personel    917xx         CA  20.00          0.0
# 4              Personal    972xx         OR  17.94          0.0
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0         Jan-1985             1.0                     NaN
# 1         Apr-1999             5.0                     NaN
# 2         Nov-2001             2.0                     NaN
# 3         Feb-1996             1.0                    35.0
# 4         Jan-1996             0.0                    38.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 0                     NaN       3.0      0.0    13648.0        83.7
# 1                     NaN       3.0      0.0     1687.0         9.4
# 2                     NaN       2.0      0.0     2956.0        98.5
# 3                     NaN      10.0      0.0     5598.0        21.0
# 4                     NaN      15.0      0.0    27783.0        53.9
#
#    total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0        9.0                   f        0.0            0.0   5861.071414
# 1        4.0                   f        0.0            0.0   1008.710000
# 2       10.0                   f        0.0            0.0   3003.653644
# 3       37.0                   f        0.0            0.0  12226.302212
# 4       38.0                   f      766.9          766.9   3242.170000
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          5831.78          5000.00         861.07                0.00
# 1          1008.71           456.46         435.17                0.00
# 2          3003.65          2400.00         603.65                0.00
# 3         12226.30         10000.00        2209.33               16.97
# 4          3242.17          2233.10        1009.07                0.00
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0        0.00                     0.00     Jan-2015           171.62
# 1      117.08                     1.11     Apr-2013           119.66
# 2        0.00                     0.00     Jun-2014           649.91
# 3        0.00                     0.00     Jan-2015           357.48
# 4        0.00                     0.00     Jan-2016            67.79
#
#   next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0          NaN           Jan-2016                         0.0
# 1          NaN           Sep-2013                         0.0
# 2          NaN           Jan-2016                         0.0
# 3          NaN           Jan-2015                         0.0
# 4     Feb-2016           Jan-2016                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN          1.0       INDIVIDUAL
# 1                          NaN          1.0       INDIVIDUAL
# 2                          NaN          1.0       INDIVIDUAL
# 3                          NaN          1.0       INDIVIDUAL
# 4                          NaN          1.0       INDIVIDUAL
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2               NaN        NaN                       NaN             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  \
# 0           NaN          NaN          NaN         NaN          NaN
# 1           NaN          NaN          NaN         NaN          NaN
# 2           NaN          NaN          NaN         NaN          NaN
# 3           NaN          NaN          NaN         NaN          NaN
# 4           NaN          NaN          NaN         NaN          NaN
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          NaN                 NaN           NaN      NaN          NaN
# 1          NaN                 NaN           NaN      NaN          NaN
# 2          NaN                 NaN           NaN      NaN          NaN
# 3          NaN                 NaN           NaN      NaN          NaN
# 4          NaN                 NaN           NaN      NaN          NaN
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          NaN         NaN       NaN               NaN     NaN          NaN
# 1          NaN         NaN       NaN               NaN     NaN          NaN
# 2          NaN         NaN       NaN               NaN     NaN          NaN
# 3          NaN         NaN       NaN               NaN     NaN          NaN
# 4          NaN         NaN       NaN               NaN     NaN          NaN
#
#    inq_last_12m  default_ind
# 0           NaN            0
# 1           NaN            1
# 2           NaN            0
# 3           NaN            0
# 4           NaN            0

# %%
data1['issue_d'] = pd.to_datetime(data1['issue_d'])

# %%
data1["issue_d"].dtypes
# Out:
# dtype('<M8[ns]')

# %%
subfile  = data1[(data1['issue_d'] >= '2015-06-01') & (data1['issue_d'] <= '2015-12-01')]

# %%
print(X_test.shape)
print(subfile.shape)
# Out:
# (256991, 21)
# (256991, 73)

# %%
Y_pred=pd.DataFrame(Y_pred)
Y_pred["prediction"]=Y_pred.iloc[:,-1]

# %%
subfile=subfile.reset_index()

# %%
sub_file=pd.concat([subfile,Y_pred.iloc[:,-1]],axis=1)

# %%
sub_file=sub_file[["id","member_id","annual_inc_joint","application_type","grade","home_ownership","verification_status","annual_inc","default_ind","prediction"]]

# %%
import numpy as np

# %%
X=["Successful Payers","Defaulters"]
default_ind=[311,256680]
prediction=[24109,232882]
explode = [0.3,0]

fig1 = plt.figure(figsize=(5,5))
plt.pie(default_ind, explode=explode, labels=X,autopct='%1.1f%%')

fig2 = plt.figure(figsize=(5,5))
plt.pie(prediction, explode=explode, labels=X,autopct='%1.1f%%')
# plt.pie(prediction,labels=X)
# Out:
# ([<matplotlib.patches.Wedge at 0xa5654ee948>,
#   <matplotlib.patches.Wedge at 0xa5665382c8>],
#  [Text(1.339636492003118, 0.40666210702938627, 'Successful Payers'),
#   Text(-1.0525715518677508, -0.31952015304001563, 'Defaulters')],
#  [Text(0.86119488771629, 0.2614256402331769, '9.4%'),
#   Text(-0.5741299373824095, -0.1742837198400085, '90.6%')])

# %%
sub_file.head()
# Out:
#          id  member_id  annual_inc_joint application_type grade  \
# 0  68587652   73477494               NaN       INDIVIDUAL     A
# 1  66624733   71350547               NaN       INDIVIDUAL     E
# 2  68446769   73336592               NaN       INDIVIDUAL     A
# 3  68595206   73484978               NaN       INDIVIDUAL     D
# 4  68587491   73477331               NaN       INDIVIDUAL     A
#
#   home_ownership verification_status  annual_inc  default_ind  prediction
# 0       MORTGAGE        Not Verified    150000.0            0           0
# 1           RENT        Not Verified    150000.0            0           1
# 2       MORTGAGE        Not Verified     59000.0            0           0
# 3       MORTGAGE        Not Verified    180000.0            0           0
# 4       MORTGAGE        Not Verified     93000.0            0           0

# %%
sub_file["prediction"].value_counts()
# Out:
# 0    232882
# 1     24109
# Name: prediction, dtype: int64

# %%
sub_file["default_ind"].value_counts()
# Out:
# 0    256680
# 1       311
# Name: default_ind, dtype: int64

# %%
sub_file["prediction"] = sub_file["prediction"].map({0 :"Defaulters",1:"Successful payers"})

# %%
sub_file.head()
# Out:
#          id  member_id  annual_inc_joint application_type grade  \
# 0  68587652   73477494               NaN       INDIVIDUAL     A
# 1  66624733   71350547               NaN       INDIVIDUAL     E
# 2  68446769   73336592               NaN       INDIVIDUAL     A
# 3  68595206   73484978               NaN       INDIVIDUAL     D
# 4  68587491   73477331               NaN       INDIVIDUAL     A
#
#   home_ownership verification_status  annual_inc  default_ind  \
# 0       MORTGAGE        Not Verified    150000.0            0
# 1           RENT        Not Verified    150000.0            0
# 2       MORTGAGE        Not Verified     59000.0            0
# 3       MORTGAGE        Not Verified    180000.0            0
# 4       MORTGAGE        Not Verified     93000.0            0
#
#           prediction
# 0         Defaulters
# 1  Successful payers
# 2         Defaulters
# 3         Defaulters
# 4         Defaulters

# %%
sub_file = sub_file.replace(to_replace ="Source Verified", value ="Verified")

# %%
sub_file["verification_status"].value_counts()
# Out:
# Verified        183815
# Not Verified     73176
# Name: verification_status, dtype: int64

# %%
sub_file.to_excel(r"G:\IMARTICUS FINAL PROJECT\Capstone_Project_File.xlsx")

# %%
plt.figure(figsize=(15,7))
plt.subplot(121)
plt.hist(x="grade",data=sub_file,bins=10,color="darkblue")
plt.title("grade")
# Out:
# Text(0.5, 1.0, 'grade')

# %%
import matplotlib.pyplot as plt

X=["Defaulters","Successful Payers"]
INDIVIDUAL = [232574,23975]
JOINT = [308,134]
explode = [0.1,0]

fig1 = plt.figure(figsize=(5,5))
plt.pie(INDIVIDUAL, explode=explode, labels=X,autopct='%1.1f%%')
plt.title("INDIVIDUAL")
plt.show()

fig2 = plt.figure(figsize=(5,5))
plt.pie(JOINT, explode=explode, labels=X,autopct='%1.1f%%')
plt.title("JOINT")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

sub_file.groupby(['verification_status','prediction']).size().unstack().plot(kind='bar',stacked=True)
plt.show()
